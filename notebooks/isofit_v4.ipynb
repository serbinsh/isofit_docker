# %%
import os
import glob
import subprocess
import sys
import time
from IPython.display import display, Image
import matplotlib.pyplot as plt
from os.path import expanduser

home = expanduser('~')
output_dir = 'isofit_output'
output_path = ''.join([os.path.join(home,'scratch/',output_dir),'/'])
os.makedirs(os.path.dirname(output_path), exist_ok=True)
print(output_path)
# Out:
# /Users/sserbin/scratch/isofit_output/

# %%
# Grab isofit_prosaild Docker container
os.system("docker pull serbinsh/isofit_containers:isofit_prosaild_master_latest")
# Out:
# 0

# %%
# check for isofit_prosaild Docker container
#os.system("docker image ls").read()
output = subprocess.check_output("docker image ls", shell=True)
print(output, sep="\t", end="\n")
# Out:
# b'REPOSITORY                       TAG                                              IMAGE ID            CREATED             SIZE\nserbinsh/isofit_containers       isofit_prosaild_master_latest                    19817f1f0dd3        2 weeks ago         2.9GB\nserbinsh/isofit_containers       <none>                                           c2e059559daf        6 weeks ago         2.9GB\ntestiso                          latest                                           7c4227088ca5        6 weeks ago         2.89GB\nserbinsh/ctsm_containers         ctsm-fates_next_api-fates_sci.1.23.0_api.7.1.0   13b838241893        8 weeks ago         1.68GB\nelm                              latest                                           7a3cd82e1966        2 months ago        1.86GB\n<none>                           <none>                                           710954a8442e        2 months ago        1.86GB\n<none>                           <none>                                           0a71d2f10572        2 months ago        1.86GB\nserbinsh/elm_containers          baseos-stable-gcc550                             4f7e6dbd13d9        2 months ago        1.22GB\nserbinsh/isofit_containers       <none>                                           0a883c84ec2b        2 months ago        2.89GB\nisofit_prosaild                  latest                                           29eb43ca7752        2 months ago        2.89GB\nprosail                          latest                                           3e8036ab78a6        2 months ago        1.41GB\nserbinsh/prosail_containers      prosail_D_basic                                  55dfd0e05ff7        2 months ago        1.18GB\nserbinsh/isofit_containers       isofit_master_latest                             c448f8debd65        2 months ago        2.9GB\nserbinsh/ctsm_containers         <none>                                           23a08adb278c        2 months ago        1.68GB\nserbinsh/ctsm_containers         ctsm-release-clm5.0.15                           119cd33fec30        2 months ago        1.41GB\nfates                            latest                                           99a91c436a42        2 months ago        1.41GB\ngcc                              7.4.0                                            3a64de0e2eee        2 months ago        1.14GB\ngcc                              6.5                                              5d343bd4a833        2 months ago        892MB\n<none>                           <none>                                           c55d4e0b6c28        2 months ago        1.37GB\nserbinsh/ctsm_containers         baseos-stable-gcc650                             1b6abe5593ea        2 months ago        1.2GB\nserbinsh/ctsm_containers         baseos-develop-gcc550                            3a23c38f3e4d        2 months ago        1.17GB\nubuntu                           latest                                           47b19964fb50        3 months ago        88.1MB\nopendronemap/node-opendronemap   latest                                           0ab9f1e6f1eb        6 months ago        3.72GB\n<none>                           <none>                                           21dda7634f30        6 months ago        200MB\n<none>                           <none>                                           6f623c57b4b7        6 months ago        454MB\n<none>                           <none>                                           a4f900e6b231        6 months ago        200MB\n<none>                           <none>                                           2a45cda85a53        6 months ago        200MB\n<none>                           <none>                                           2d10e1e1d4b5        6 months ago        454MB\ncentos                           6.10                                             30e66b619e9f        7 months ago        194MB\ncentos                           centos6.10                                       30e66b619e9f        7 months  ...

# %%
# Setup isofit run options and inputs
docker_name = "serbinsh/isofit_containers:isofit_prosaild_master_latest"
host_output_dir = output_path
docker_output_dir = "/isofit/examples/20171108_Pasadena/"
print(''.join([host_output_dir,":",docker_output_dir]))
#
examples = "/isofit/examples/20171108_Pasadena"
run_command = ''.join(["/bin/sh -c ","'cd ",examples," && ./run_example_libradtran.sh'"])
print(run_command)
# Out:
# /Users/sserbin/scratch/isofit_output/:/isofit/examples/20171108_Pasadena/
# /bin/sh -c 'cd /isofit/examples/20171108_Pasadena && ./run_example_libradtran.sh'

# %%
# Setup full run call
run = ''.join(["docker run --user isofit -v ",host_output_dir,":",docker_output_dir,"output -v ", host_output_dir,"/images:",docker_output_dir,"images -v ",host_output_dir,"/lut:",docker_output_dir,"lut"," ",docker_name," ",run_command])
print(run)
# Out:
# docker run --user isofit -v /Users/sserbin/scratch/isofit_output/:/isofit/examples/20171108_Pasadena/output -v /Users/sserbin/scratch/isofit_output//images:/isofit/examples/20171108_Pasadena/images -v /Users/sserbin/scratch/isofit_output//lut:/isofit/examples/20171108_Pasadena/lut serbinsh/isofit_containers:isofit_prosaild_master_latest /bin/sh -c 'cd /isofit/examples/20171108_Pasadena && ./run_example_libradtran.sh'

# %%
# Run isofit
start = time.time()
# run the docker container
os.system(run)
# get runtime
end = time.time()
#Print runtime
print(end - start)
# Out:
# 448.3947389125824

# %%
# show output frames
images_dir = os.path.join(output_path,'images')
print(images_dir)
# Out:
# /Users/sserbin/scratch/isofit_output/images

# %%
# frame_0
file0 = ''.join([images_dir,"/frame_0.png"])
Image(filename=file0)

# %%
# frame_1
file1 = ''.join([images_dir,"/frame_1.png"])
Image(filename=file1)

# %%
# frame_2
file2 = ''.join([images_dir,"/frame_2.png"])
Image(filename=file2)

# %%
# frame_3
file3 = ''.join([images_dir,"/frame_3.png"])
Image(filename=file3)

# %%
# Plot main reflectance output
for files in glob.glob(os.path.join(output_path,"*_rfl_*")):
    f = open( files, 'r' )
    file_contents = f.read()
    print(f.name)
    filename_in = f.name
    f.close()
    
f2 = open(filename_in, 'r') 
lines = f2.readlines()
x = []
y = [] 
for line in lines:
    p = line.split()
    x.append(float(p[0]))
    y.append(float(p[1]))
f2.close() 

#plt.plot(x,y, label='IsoFit Surface Reflectance')
plt.plot(x,y)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Reflectance (0-1)')
plt.axis([400, 2500, 0, 1])
plt.legend(['IsoFit Surface Reflectance'])
#plt.show()
plt.savefig(''.join([output_path,'isofit_reflectance.png']))
plt.close(fig='all')

refl = ''.join([output_path,"/isofit_reflectance.png"])
Image(filename=refl)
# Out:
# /Users/sserbin/scratch/isofit_output/ang20171108t184227_rfl_v2p11_BeckmanLawn-libRadTran.txt

# %%
for files in glob.glob(os.path.join(output_path,"*_mdl_*")):
    f = open( files, 'r' )
    file_contents = f.read()
    print(f.name)
    filename_in = f.name
    f.close()
    
f2 = open(filename_in, 'r') 
lines = f2.readlines()
x = []
y = [] 
for line in lines:
    p = line.split()
    x.append(float(p[0]))
    y.append(float(p[1]))
f2.close() 

plt.plot(x,y)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Apparent surface reflectance')
plt.legend(['Beckman Lawn, radiance on orbit'])
#plt.show()
plt.savefig(''.join([output_path,'isofit_radiance.png']))
plt.close(fig='all')

radiance = ''.join([output_path,'/isofit_radiance.png'])
Image(filename=radiance)
# Out:
# /Users/sserbin/scratch/isofit_output/ang20171108t184227_mdl_v2p11_BeckmanLawn-libRadTran.txt
